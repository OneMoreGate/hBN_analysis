# %%
import matplotlib.pyplot as plt 
import matplotlib.ticker as ticker
import pandas as pd 
import numpy as np 
import good_collections as gc
import functions as func
import scipy as sp
import os

# %%
contact_4 = {'4': gc.ifs_4}
contact_5 = {'5': gc.ifs_5}
contact_16 = {'16': gc.ifs_16}
contact_17 = {'17': gc.ifs_17}
contact_26_B = {'26.B': gc.ifs_26_B}
contact_list = [contact_4, contact_16, contact_17, contact_26_B]
contact_names = ['4', '16', '17', '26.B']
data_path = 'hBN_1'

path = os.path.abspath(os.getcwd())[:-6]
path
# Out:
# 'c:\\Users\\Никита Жидков\\Documents\\GitHub\\hBN_analysis'

# %%
for i in range(len(contact_list)):    
    fig, ax = plt.subplots(ncols=1, nrows=1, figsize = [7,5])
    func.draw_list_of_data(ax, data_path, contact_list[i])
    func.draw_color_gradient('#FF0A0A', '#0A10FF', ax)
    ax.set_yscale('log')
    ax.set_ylim([10**(-10), 0.01])
    ax.set_xlim([-3.25,3.25])
    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.25))
    ax.tick_params(axis='x', labelsize=15)
    ax.tick_params(axis='y', labelsize=15)
    ax.set_xlabel('Напряжение, В', size = 17)
    ax.set_ylabel('Ток, А', size = 17)
    #ax.set_title(contact_names[i])
    save_path = path + '\\' +  'change_state_' + contact_names[i] + '.png'
    plt.savefig(save_path, dpi = 300, bbox_inches = 'tight')
    plt.close(fig)

# %%
upper = {'5': [113]}
lower = {'5': [94]}
midle = {'5': [108]}

fig, ax = plt.subplots(ncols=1, nrows=3, figsize = [5,7])
fig.tight_layout(pad=2)

for i in range(len(ax)):
    ax[i].set_yscale('log')
    ax[i].set_ylim([10**(-10), 0.01])
    ax[i].set_xlim([-3.25,3.25])
    ax[i].xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax[i].xaxis.set_minor_locator(ticker.MultipleLocator(0.25))
    ax[i].tick_params(axis='x', labelsize=15)
    ax[i].tick_params(axis='y', labelsize=15)


func.draw_list_of_data(ax[0], data_path, lower)
func.draw_list_of_data(ax[0], data_path, midle)
func.draw_list_of_data(ax[0], data_path, upper)
lines_1 = ax[0].get_lines()
lines_1[2].set_color('r')
lines_1[2].set_linewidth(2)

func.draw_list_of_data(ax[1], data_path, upper)
func.draw_list_of_data(ax[1], data_path, midle)
func.draw_list_of_data(ax[1], data_path, lower)
lines_2 = ax[1].get_lines()
lines_2[2].set_color('b')
lines_2[2].set_linewidth(2)

func.draw_list_of_data(ax[2], data_path, lower)
func.draw_list_of_data(ax[2], data_path, upper)
func.draw_list_of_data(ax[2], data_path, midle)
lines_3 = ax[2].get_lines()
lines_3[2].set_color('k')
lines_3[2].set_linewidth(2)

ax[2].set_xlabel('Напряжение, В', size = 17)
ax[1].set_ylabel('Ток, А', size = 17)

plt.savefig(path + '\\' +  'multystate_device.png', dpi = 300, bbox_inches = 'tight')

# %%
fig, ax = plt.subplots(figsize = [7,5])
I = func.read_on_off_stat(data_path, contact_list[0], 1)
I_off = I['I_off'] * 1000000
measurment = range(len(I_off))
ax.plot(measurment, I_off)
ax.set_ylim([5, 25])
ax.set_xlim([-2.5,55])
ax.yaxis.set_major_locator(ticker.MultipleLocator(5))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(1))
ax.xaxis.set_major_locator(ticker.MultipleLocator(10))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(2.5))
ax.tick_params(axis='x', labelsize=15)
ax.tick_params(axis='y', labelsize=15)
ax.set_title(contact_names[0])
ax.set_xlabel('Номер измерения', size = 17)
ax.set_ylabel(r'$I_{off}$ ,$\mu A$', size = 17)
#plt.savefig(path + '\\' +  'I_off_shif_' + contact_names[0] + '.png', dpi = 300, bbox_inches = 'tight')
# Out:
# Text(0, 0.5, '$I_{off}$ ,$\\mu A$')

# %%
fig, ax = plt.subplots(figsize = [7,5])
I = func.read_on_off_stat(data_path, contact_list[1], 1)
I_off = I['I_off'] * 1000000
measurment = range(len(I_off))
ax.plot(measurment, I_off)
ax.set_ylim([0, 15])
ax.set_xlim([-2.5,100])
ax.yaxis.set_major_locator(ticker.MultipleLocator(5))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(1))
ax.xaxis.set_major_locator(ticker.MultipleLocator(10))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(2.5))
ax.tick_params(axis='x', labelsize=15)
ax.tick_params(axis='y', labelsize=15)
ax.set_title(contact_names[1])
ax.set_xlabel('Номер измерения', size = 17)
ax.set_ylabel(r'$I_{off}$ ,$\mu A$', size = 17)
#plt.savefig(path + '\\' +  'I_off_shif_' + contact_names[1] + '.png', dpi = 300, bbox_inches = 'tight')
# Out:
# Text(0, 0.5, '$I_{off}$ ,$\\mu A$')

# %%
fig, ax = plt.subplots(figsize = [7,5])
I = func.read_on_off_stat(data_path, contact_list[2], 1)
I_off = I['I_off'] * 1000000
measurment = range(len(I_off))
ax.plot(measurment, I_off)
ax.set_ylim([1, 6])
ax.set_xlim([-2.5,45])
ax.yaxis.set_major_locator(ticker.MultipleLocator(1))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.25))
ax.xaxis.set_major_locator(ticker.MultipleLocator(10))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(2.5))
ax.tick_params(axis='x', labelsize=15)
ax.tick_params(axis='y', labelsize=15)
ax.set_title(contact_names[2])
ax.set_xlabel('Номер измерения', size = 17)
ax.set_ylabel(r'$I_{off}$ ,$\mu A$', size = 17)
#plt.savefig(path + '\\' +  'I_off_shif_' + contact_names[2] + '.png', dpi = 300, bbox_inches = 'tight')
# Out:
# Text(0, 0.5, '$I_{off}$ ,$\\mu A$')

# %%
fig, ax = plt.subplots(ncols=1, nrows=1, figsize = [7,5])
I = func.read_on_off_stat(data_path, contact_list[3], 1)
I_on = I['I_on']* 1000000
I_off = I['I_off'] * 1000000
measurment = range(len(I_off))

ax.plot(measurment, I_off)
ax.set_ylim([0, 1])
ax.set_xlim([-2.5,42.5])
ax.yaxis.set_major_locator(ticker.MultipleLocator(0.25))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.05))
ax.xaxis.set_major_locator(ticker.MultipleLocator(10))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(2.5))
ax.tick_params(axis='x', labelsize=15)
ax.tick_params(axis='y', labelsize=15)
ax.set_title(contact_names[3])
ax.set_xlabel('Номер измерения', size = 17)
ax.set_ylabel(r'$I_{off}$ ,$\mu A$', size = 17)
#plt.savefig(path + '\\' +  'I_off_shif_' + contact_names[3] + '.png', dpi = 300, bbox_inches = 'tight')
# Out:
# Text(0, 0.5, '$I_{off}$ ,$\\mu A$')

# %%
fig, ax = plt.subplots(ncols=1, nrows=2, figsize = [5,7])
I = func.read_on_off_stat(data_path, contact_list[1], 1)
I_on = I['I_on'] * 1000000
I_off = I['I_off'] * 1000000
measurment = range(len(I_off))

ax[0].plot(measurment, I_on)
ax[0].set_ylim([350, 700])
ax[0].set_xlim([-2.5,100])
ax[0].yaxis.set_major_locator(ticker.MultipleLocator(50))
ax[0].yaxis.set_minor_locator(ticker.MultipleLocator(10))
ax[0].xaxis.set_major_locator(ticker.MultipleLocator(10))
ax[0].xaxis.set_minor_locator(ticker.MultipleLocator(2.5))
ax[0].tick_params(axis='x', labelsize=15)
ax[0].tick_params(axis='y', labelsize=15)
#ax[0].set_title(contact_names[1])
#ax[0].set_xlabel('Номер измерения', size = 17)
ax[0].set_ylabel(r'$I_{on}$ ,$\mu A$', size = 17)

ax[1].plot(measurment, I_off)
ax[1].set_ylim([0, 15])
ax[1].set_xlim([-2.5,100])
ax[1].yaxis.set_major_locator(ticker.MultipleLocator(2.5))
ax[1].yaxis.set_minor_locator(ticker.MultipleLocator(0.5))
ax[1].xaxis.set_major_locator(ticker.MultipleLocator(10))
ax[1].xaxis.set_minor_locator(ticker.MultipleLocator(2.5))
ax[1].tick_params(axis='x', labelsize=15)
ax[1].tick_params(axis='y', labelsize=15)
#ax[1].set_title(contact_names[1])
ax[1].set_xlabel('Номер измерения', size = 17)
ax[1].set_ylabel(r'$I_{off}$ ,$\mu A$', size = 17)

plt.savefig(path + '\\' +  'I_on_off_shift_' + contact_names[1] + '.png', dpi = 300, bbox_inches = 'tight')

# %%
fig, ax = plt.subplots(ncols=1, nrows=2, figsize = [5,7])
I = func.read_on_off_stat(data_path, contact_list[3], 1)
I_on = I['I_on'] * 1000000
I_off = I['I_off'] * 1000000
measurment = range(len(I_off))

ax[0].plot(measurment, I_on)
ax[0].set_ylim([25, 50])
ax[0].set_xlim([-2.5,42.5])
ax[0].yaxis.set_major_locator(ticker.MultipleLocator(5))
ax[0].yaxis.set_minor_locator(ticker.MultipleLocator(1))
ax[0].xaxis.set_major_locator(ticker.MultipleLocator(10))
ax[0].xaxis.set_minor_locator(ticker.MultipleLocator(2.5))
ax[0].tick_params(axis='x', labelsize=15)
ax[0].tick_params(axis='y', labelsize=15)
#ax[0].set_title(contact_names[3])
#ax[0].set_xlabel('Номер измерения', size = 17)
ax[0].set_ylabel(r'$I_{on}$ ,$\mu A$', size = 17)

ax[1].plot(measurment, I_off)
ax[1].set_ylim([0, 1])
ax[1].set_xlim([-2.5,42.5])
ax[1].yaxis.set_major_locator(ticker.MultipleLocator(0.25))
ax[1].yaxis.set_minor_locator(ticker.MultipleLocator(0.05))
ax[1].xaxis.set_major_locator(ticker.MultipleLocator(10))
ax[1].xaxis.set_minor_locator(ticker.MultipleLocator(2.5))
ax[1].tick_params(axis='x', labelsize=15)
ax[1].tick_params(axis='y', labelsize=15)
#ax[1].set_title(contact_names[3])
ax[1].set_xlabel('Номер измерения', size = 17)
ax[1].set_ylabel(r'$I_{off}$ ,$\mu A$', size = 17)
plt.savefig(path + '\\' +  'I_on_off_shift_' + contact_names[3] + '.png', dpi = 300, bbox_inches = 'tight')

# %%
fig, ax = plt.subplots(ncols=1, nrows=2, figsize = [5,7])
I = func.read_on_off_stat(data_path, contact_list[2], 1)
I_on = I['I_on'] * 1000000
I_off = I['I_off'] * 1000000
measurment = range(len(I_off))

ax[0].plot(measurment, I_on)
ax[0].set_ylim([20, 100])
ax[0].set_xlim([-2.5,45])
ax[0].yaxis.set_major_locator(ticker.MultipleLocator(20))
ax[0].yaxis.set_minor_locator(ticker.MultipleLocator(5))
ax[0].xaxis.set_major_locator(ticker.MultipleLocator(10))
ax[0].xaxis.set_minor_locator(ticker.MultipleLocator(2.5))
ax[0].tick_params(axis='x', labelsize=15)
ax[0].tick_params(axis='y', labelsize=15)
#ax[0].set_title(contact_names[2])
#ax[0].set_xlabel('Номер измерения', size = 17)
ax[0].set_ylabel(r'$I_{on}$ ,$\mu A$', size = 17)

ax[1].plot(measurment, I_off)
ax[1].set_ylim([1, 6])
ax[1].set_xlim([-2.5,45])
ax[1].yaxis.set_major_locator(ticker.MultipleLocator(1))
ax[1].yaxis.set_minor_locator(ticker.MultipleLocator(0.25))
ax[1].xaxis.set_major_locator(ticker.MultipleLocator(10))
ax[1].xaxis.set_minor_locator(ticker.MultipleLocator(2.5))
ax[1].tick_params(axis='x', labelsize=15)
ax[1].tick_params(axis='y', labelsize=15)
#ax[1].set_title(contact_names[2])
ax[1].set_xlabel('Номер измерения', size = 17)
ax[1].set_ylabel(r'$I_{off}$ ,$\mu A$', size = 17)
plt.savefig(path + '\\' +  'I_on_off_shift_' + contact_names[2] + '.png', dpi = 300, bbox_inches = 'tight')

# %%
fig, ax = plt.subplots(ncols=1, nrows=2, figsize = [5,7])
I = func.read_on_off_stat(data_path, contact_list[0], 1)
I_on = I['I_on'] * 1000000
I_off = I['I_off'] * 1000000
measurment = range(len(I_off))

ax[0].plot(measurment, I_on)
ax[0].set_ylim([100, 300])
ax[0].set_xlim([-2.5,55])
ax[0].yaxis.set_major_locator(ticker.MultipleLocator(50))
ax[0].yaxis.set_minor_locator(ticker.MultipleLocator(10))
ax[0].xaxis.set_major_locator(ticker.MultipleLocator(10))
ax[0].xaxis.set_minor_locator(ticker.MultipleLocator(2.5))
ax[0].tick_params(axis='x', labelsize=15)
ax[0].tick_params(axis='y', labelsize=15)
#ax[0].set_title(contact_names[0])
#ax[0].set_xlabel('Номер измерения', size = 17)
ax[0].set_ylabel(r'$I_{on}$ ,$\mu A$', size = 17)

ax[1].plot(measurment, I_off)
ax[1].set_ylim([5, 25])
ax[1].set_xlim([-2.5,55])
ax[1].yaxis.set_major_locator(ticker.MultipleLocator(5))
ax[1].yaxis.set_minor_locator(ticker.MultipleLocator(1))
ax[1].xaxis.set_major_locator(ticker.MultipleLocator(10))
ax[1].xaxis.set_minor_locator(ticker.MultipleLocator(2.5))
ax[1].tick_params(axis='x', labelsize=15)
ax[1].tick_params(axis='y', labelsize=15)
#ax[1].set_title(contact_names[0])
ax[1].set_xlabel('Номер измерения', size = 17)
ax[1].set_ylabel(r'$I_{off}$ ,$\mu A$', size = 17)
plt.savefig(path + '\\' +  'I_on_off_shift_' + contact_names[0] + '.png', dpi = 300, bbox_inches = 'tight')

# %%
typical_16 = {'16': [57]}
fig, ax = plt.subplots(ncols=1, nrows=1, figsize = [7,5])
func.draw_list_of_data(ax, data_path, typical_16)
ax.set_yscale('log')
ax.set_ylim([10**(-10), 0.005])
ax.set_xlim([-3,3])
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.25))
ax.tick_params(axis='x', labelsize=15)
ax.tick_params(axis='y', labelsize=15)
ax.set_xlabel('Напряжение, В', size = 17)
ax.set_ylabel('Ток, А', size = 17)
line = ax.get_lines()
line[0].set_color('k')
line[0].set_linewidth(2)

plt.savefig(path + '\\' +  'typical_16.png', dpi = 300, bbox_inches = 'tight')

# %%
typical_4 = {'4': [50]}
fig, ax = plt.subplots(ncols=1, nrows=1, figsize = [7,5])
func.draw_list_of_data(ax, data_path, typical_4)
ax.set_yscale('log')
ax.set_ylim([10**(-10), 0.005])
ax.set_xlim([-3,3])
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.25))
ax.tick_params(axis='x', labelsize=15)
ax.tick_params(axis='y', labelsize=15)
ax.set_xlabel('Напряжение, В', size = 17)
ax.set_ylabel('Ток, А', size = 17)
line = ax.get_lines()
line[0].set_color('k')
line[0].set_linewidth(2)

plt.savefig(path + '\\' +  'typical_4.png', dpi = 300, bbox_inches = 'tight')

# %%
typical_17 = {'17': [50]}
fig, ax = plt.subplots(ncols=1, nrows=1, figsize = [7,5])
func.draw_list_of_data(ax, data_path, typical_17)
ax.set_yscale('log')
ax.set_ylim([10**(-10), 0.005])
ax.set_xlim([-3,3])
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.25))
ax.tick_params(axis='x', labelsize=15)
ax.tick_params(axis='y', labelsize=15)
ax.set_xlabel('Напряжение, В', size = 17)
ax.set_ylabel('Ток, А', size = 17)
line = ax.get_lines()
line[0].set_color('k')
line[0].set_linewidth(2)
#os.chdir(path)
plt.savefig( path + '\\' + 'typical_17.png', dpi = 300, bbox_inches = 'tight')

# %%
typical_26_B = {'26.B': [62]}
fig, ax = plt.subplots(ncols=1, nrows=1, figsize = [7,5])
func.draw_list_of_data(ax, data_path, typical_26_B)
ax.set_yscale('log')
ax.set_ylim([10**(-10), 0.005])
ax.set_xlim([-3,3])
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.25))
ax.tick_params(axis='x', labelsize=15)
ax.tick_params(axis='y', labelsize=15)
ax.set_xlabel('Напряжение, В', size = 17)
ax.set_ylabel('Ток, А', size = 17)
line = ax.get_lines()
line[0].set_color('k')
line[0].set_linewidth(2)

plt.savefig(path +   'typical_26_B.png', dpi = 300, bbox_inches = 'tight')

# %%
on_off_V = func.get_on_off_voltage(data_path, contact_4)
V_off = on_off_V.transpose()[1]
V_on = on_off_V.transpose()[0]

fig, ax = plt.subplots(ncols=1, nrows=2, figsize = [6,4])
n = np.arange(len(contact_4['4']))
ax[0].plot(n, V_off)
ax[0].set_ylabel(r'$V_{off},$ V', size = 17)
ax[0].yaxis.set_major_locator(ticker.MultipleLocator(0.25))
ax[0].yaxis.set_minor_locator(ticker.MultipleLocator(0.05))
ax[0].xaxis.set_major_locator(ticker.MultipleLocator(10))
ax[0].xaxis.set_minor_locator(ticker.MultipleLocator(2.5))
ax[0].set_ylim([1.75, 2.75])
ax[0].set_xlim([-2.5,55])
ax[0].tick_params(axis='x', labelsize=15)
ax[0].tick_params(axis='y', labelsize=15)
ax[0].xaxis.set_tick_params(direction='in', which = 'both')
ax[0].yaxis.set_tick_params(direction='in', which = 'both')
ax[0].set_title('Контакт 4', size = 17)

ax[1].plot(n, V_on)
ax[1].set_ylabel(r'$V_{on},$ V', size = 17)
ax[1].yaxis.set_major_locator(ticker.MultipleLocator(0.5))
ax[1].yaxis.set_minor_locator(ticker.MultipleLocator(0.1))
ax[1].xaxis.set_major_locator(ticker.MultipleLocator(10))
ax[1].xaxis.set_minor_locator(ticker.MultipleLocator(2.5))
ax[1].set_ylim([-2.5, -1])
ax[1].set_xlim([-2.5, 55])
ax[1].tick_params(axis='x', labelsize=15)
ax[1].tick_params(axis='y', labelsize=15)
ax[1].set_xlabel('Номер измерения', size = 17)
ax[1].xaxis.set_tick_params(direction='in', which = 'both')
ax[1].yaxis.set_tick_params(direction='in', which = 'both')
plt.savefig(path + '\\' +  'V_on_off_4.png', dpi = 300, bbox_inches = 'tight')

# %%
on_off_V = func.get_on_off_voltage(data_path, contact_16)
V_off = on_off_V.transpose()[1]
V_on = on_off_V.transpose()[0]

fig, ax = plt.subplots(ncols=1, nrows=2, figsize = [6,4])
n = np.arange(len(contact_16['16']))
ax[0].plot(n, V_off)
ax[0].set_ylabel(r'$V_{off},$ V', size = 17)
ax[0].yaxis.set_major_locator(ticker.MultipleLocator(0.25))
ax[0].yaxis.set_minor_locator(ticker.MultipleLocator(0.05))
ax[0].xaxis.set_major_locator(ticker.MultipleLocator(10))
ax[0].xaxis.set_minor_locator(ticker.MultipleLocator(2.5))
ax[0].set_ylim([1.5, 2.5])
ax[0].set_xlim([-2.5,100])
ax[0].tick_params(axis='x', labelsize=15)
ax[0].tick_params(axis='y', labelsize=15)
ax[0].xaxis.set_tick_params(direction='in', which = 'both')
ax[0].yaxis.set_tick_params(direction='in', which = 'both')
ax[0].set_title('Контакт 16', size = 17)

ax[1].plot(n, V_on)
ax[1].set_ylabel(r'$V_{on},$ V', size = 17)
ax[1].yaxis.set_major_locator(ticker.MultipleLocator(0.5))
ax[1].yaxis.set_minor_locator(ticker.MultipleLocator(0.1))
ax[1].xaxis.set_major_locator(ticker.MultipleLocator(10))
ax[1].xaxis.set_minor_locator(ticker.MultipleLocator(2.5))
ax[1].set_ylim([-3, -1.5])
ax[1].set_xlim([-2.5, 100])
ax[1].tick_params(axis='x', labelsize=15)
ax[1].tick_params(axis='y', labelsize=15)
ax[1].set_xlabel('Номер измерения', size = 17)
ax[1].xaxis.set_tick_params(direction='in', which = 'both')
ax[1].yaxis.set_tick_params(direction='in', which = 'both')

plt.savefig(path + '\\' +  'V_on_off_16.png', dpi = 300, bbox_inches = 'tight')

# %%
on_off_V = func.get_on_off_voltage(data_path, contact_17)
V_off = on_off_V.transpose()[1]
V_on = on_off_V.transpose()[0]

fig, ax = plt.subplots(ncols=1, nrows=2, figsize = [6,4])
n = np.arange(len(contact_17['17']))
ax[0].plot(n, V_off)
ax[0].set_ylabel(r'$V_{off},$ V', size = 17)
ax[0].yaxis.set_major_locator(ticker.MultipleLocator(0.5))
ax[0].yaxis.set_minor_locator(ticker.MultipleLocator(0.1))
ax[0].xaxis.set_major_locator(ticker.MultipleLocator(10))
ax[0].xaxis.set_minor_locator(ticker.MultipleLocator(2.5))
ax[0].set_ylim([1, 2.5])
ax[0].set_xlim([-2.5,45])
ax[0].tick_params(axis='x', labelsize=15)
ax[0].tick_params(axis='y', labelsize=15)
ax[0].xaxis.set_tick_params(direction='in', which = 'both')
ax[0].yaxis.set_tick_params(direction='in', which = 'both')
ax[0].set_title('Контакт 17', size = 17)

ax[1].plot(n, V_on)
ax[1].set_ylabel(r'$V_{on},$ V', size = 17)
ax[1].yaxis.set_major_locator(ticker.MultipleLocator(0.5))
ax[1].yaxis.set_minor_locator(ticker.MultipleLocator(0.1))
ax[1].xaxis.set_major_locator(ticker.MultipleLocator(10))
ax[1].xaxis.set_minor_locator(ticker.MultipleLocator(2.5))
ax[1].set_ylim([-2.5, -1])
ax[1].set_xlim([-2.5, 45])
ax[1].tick_params(axis='x', labelsize=15)
ax[1].tick_params(axis='y', labelsize=15)
ax[1].set_xlabel('Номер измерения', size = 17)
ax[1].xaxis.set_tick_params(direction='in', which = 'both')
ax[1].yaxis.set_tick_params(direction='in', which = 'both')

plt.savefig(path + '\\' +  'V_on_off_17.png', dpi = 300, bbox_inches = 'tight')

# %%
on_off_V = func.get_on_off_voltage(data_path, contact_26_B)
V_off = on_off_V.transpose()[1]
V_on = on_off_V.transpose()[0]

fig, ax = plt.subplots(ncols=1, nrows=2, figsize = [6,4])
n = np.arange(len(contact_26_B['26.B']))
ax[0].plot(n, V_off)
ax[0].set_ylabel(r'$V_{off},$ V', size = 17)
ax[0].yaxis.set_major_locator(ticker.MultipleLocator(0.25))
ax[0].yaxis.set_minor_locator(ticker.MultipleLocator(0.05))
ax[0].xaxis.set_major_locator(ticker.MultipleLocator(10))
ax[0].xaxis.set_minor_locator(ticker.MultipleLocator(2.5))
ax[0].set_ylim([2, 3])
ax[0].set_xlim([-2.5,42.5])
ax[0].tick_params(axis='x', labelsize=15)
ax[0].tick_params(axis='y', labelsize=15)
ax[0].xaxis.set_tick_params(direction='in', which = 'both')
ax[0].yaxis.set_tick_params(direction='in', which = 'both')
ax[0].set_title('Контакт 26.B', size = 17)

ax[1].plot(n, V_on)
ax[1].set_ylabel(r'$V_{on},$ V', size = 17)
ax[1].yaxis.set_major_locator(ticker.MultipleLocator(0.5))
ax[1].yaxis.set_minor_locator(ticker.MultipleLocator(0.1))
ax[1].xaxis.set_major_locator(ticker.MultipleLocator(10))
ax[1].xaxis.set_minor_locator(ticker.MultipleLocator(2.5))
ax[1].set_ylim([-3, -1])
ax[1].set_xlim([-2.5, 42.5])
ax[1].tick_params(axis='x', labelsize=15)
ax[1].tick_params(axis='y', labelsize=15)
ax[1].set_xlabel('Номер измерения', size = 17)
ax[1].xaxis.set_tick_params(direction='in', which = 'both')
ax[1].yaxis.set_tick_params(direction='in', which = 'both')

plt.savefig(path + '\\' +  'V_on_off_26.B.png', dpi = 300, bbox_inches = 'tight')

# %%
import matplotlib.pyplot as plt 
import matplotlib.ticker as ticker
import pandas as pd 
import numpy as np 
import os
import shutil

def get_colors_from_cmap(cmap_name: str, array_lenght: int) -> list:
    cmap = plt.get_cmap(cmap_name)
    individual_colors = [cmap(i / array_lenght) for i in range(array_lenght)]
    return individual_colors

def graph_DC_IV(data_path: str, save_path: str, name: str):
    df = pd.read_csv(data_path, delimiter='   ', skiprows=16, engine='python', header=None, encoding='ISO-8859-1').astype(np.float32)
    fig, ax = plt.subplots(ncols=1, nrows=1, figsize = [10,5])
    colors = get_colors_from_cmap('plasma', len(df[0]))
    get_gradient_line(ax, V=df[0], I=df[1], colors = colors)
    ax.set_yscale('log')
    #ax.set_xlim([-5,5])
    #ax.set_ylim([10**(-8), 10**(-2)])
    #ax.set_title(f'{i} measurment with {lines[10].split()[1]} positive complines')
    ax.grid(which='major', linewidth = 0.6)
    ax.grid(which='minor', linewidth = 0.2)
    #ax.xaxis.set_major_locator(ticker.MultipleLocator(0.5))
    #ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.1))
    sm = plt.cm.ScalarMappable(cmap=plt.cm.plasma, norm=plt.Normalize(vmin=0, vmax=len(df[0])))
    cbar = fig.colorbar(sm)
    cbar.set_ticks([0,len(df[0])])
    cbar.set_ticklabels(['start','end'])
    cbar.set_label('sequence of measurements', size = 15)
    plt.savefig(save_path + f'\\{name}.png', dpi = 300, bbox_inches = 'tight')
    plt.clf()
    plt.close(fig)

def create_dir(path: str):
    if os.path.isdir(path):
        shutil.rmtree(path, ignore_errors=True)
        os.mkdir(path)
    else:
        os.mkdir(path)

def get_gradient_line(ax, V, I, colors):
    for i in range(len(V)-1):
        ax.plot([V[i], V[i+1]], np.abs([I[i], I[i+1]]), c = colors[i], linewidth = 2)

def all_graphs(data_path: str) :
    # чтение всех вложенных директорий и разделение на файлы и папки
    dir_list = []
    file_list = []
    for i in os.listdir(data_path):
        if os.path.isdir(f'{data_path}/{i}'):
            dir_list.append(f'{i}')
        else:
            file_list.append(f'{i}')

    # составляем список header файлов по имющимся папкам
    header_list = []
    for i in dir_list:
        if f'{i}.header' in file_list:
            header_list.append(f'{i}.header')

    # считываем данные об измерениях из header файлов
    splite_line = '______________________________________________________'
    all_contacts_info = {}
    for i in header_list:
        with open(f'{data_path}\{i}') as f:
            header_lines = []
            for k in f.readlines()[:-2]:
                header_lines.append(k.replace('\n', ''))
            # информация о всех отдельных измерениях на одном контакте
            single_contact_info = {}
            for j in range(len(header_lines)):
                if header_lines[j] == splite_line:
                    number, *m_type = header_lines[j + 3].split()
                    file_path = header_lines[j + 8].split()[-1]
                    single_contact_info[int(number)] = {'type': ' '.join(m_type), 'file_path': file_path}
                else:
                    continue
        all_contacts_info[i.replace('.header', '')] =  single_contact_info

    # рисуем графики для всех файлов во всех папках
    # создаем общую папку для графиков
    glodal_graph_path = '_'.join([data_path, 'graphs'])
    create_dir(glodal_graph_path)

    # создаем папки с графиками для каждого контакта и рисуем графики
    for i in range(len(dir_list)):
        single_contact_path = '\\'.join([data_path, dir_list[i]])
        local_graph_path = '\\'.join([glodal_graph_path, dir_list[i]])
        create_dir(local_graph_path)
        for j in os.listdir(single_contact_path):
            data_number = int(j.split('.')[0])
            local_data_path = f'{data_path}' + all_contacts_info[dir_list[i]][data_number]['file_path']
            match all_contacts_info[dir_list[i]][data_number]['type']:
                case 'DC IV':
                    graph_DC_IV(local_data_path, local_graph_path, str(data_number))
# Out:
# C:\Users\Никита Жидков\AppData\Local\Temp\ipykernel_5720\2051659993.py:27: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = fig.colorbar(sm)
# C:\Users\Никита Жидков\AppData\Local\Temp\ipykernel_5720\2051659993.py:27: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = fig.colorbar(sm)
# ...
